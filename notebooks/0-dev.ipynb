# %%
# %matplotlib inline

import torch
import torch.nn as nn
import torchvision
import kornia.augmentation as K

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi': 300, 'figure.figsize': (9, 6)})

# %%
from ggt.data import FITSDataset, get_data_loader
from ggt.utils import discover_devices

# %% [markdown]
# ## Scratch work

# %%
data_dir = "../data/sdss/"
slug = "balanced-lg"

# %% [markdown]
# ### Augmentation with `kornia`

# %% [markdown]
# Let's verify that `kornia` augmentation is working as expected.

# %%
T = nn.Sequential(
    K.RandomRotation(360),
    K.RandomHorizontalFlip(),
    K.RandomVerticalFlip(),
)

# %%
dataset = FITSDataset(data_dir, slug=slug, normalize=True, transform=T, split='train')
# Out:
# ...
# 100%|██████████| 22510/22510 [00:05<00:00, 4095.04it/s]

# %%
Xs = list(map(lambda _: dataset[2342][0], range(25)))
y = dataset[2342][1]

# %%
plt.axis('off')
plt.imshow(tensor_to_numpy(torchvision.utils.make_grid(Xs, nrow=5, pad_value=1)))
plt.show()
